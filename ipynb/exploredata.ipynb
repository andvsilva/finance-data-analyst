# %%
import pandas as pd

# %%
banking = pd.read_csv('../dataset/banking.csv')
banking.drop(["Unnamed: 0"], axis=1, inplace=True)
banking
# Out:
#           date   cca   ccb          descricao  debito  credito  movimentacao  \
# 0   2023-01-03  8608  1409    Kelly Hernandez  567060    42586        497165
# 1   2022-11-16  9020  5033  Michael Wilkinson  132674   776325        951505
# 2   2023-01-18  2945  3968  James Blankenship  398416   542904        316851
# 3   2023-01-05  2086  1609        Eric Porter  696861   839881         99553
# 4   2022-11-21  5482  2593      Stacey Hodges  233882   338897        700719
# ..         ...   ...   ...                ...     ...      ...           ...
# 95  2022-11-24  9885  8567        Laura Jones  279447   675007        344304
# 96  2022-11-03  2918  8307       David Rogers  653149     5933        709948
# 97  2023-01-08  4227  1191       Breanna King  526405   794629        351285
# 98  2022-12-10  7602  8470       Renee Little  555844   281129        576104
# 99  2023-01-18  2211  8555      Joanna Orozco  678892   458279        509409
#
# ...

# %%
print(f"Shape dataset Full:.........observations/rows: {banking.shape[0]} and columns: {banking.shape[1]}")
# Out:
# Shape dataset Full:.........observations/rows: 100 and columns: 15

# %%
banking.dtypes
# Out:
# date                 object
# cca                   int64
# ccb                   int64
# descricao            object
# debito                int64
# credito               int64
# movimentacao          int64
# cc_id                 int64
# cc_descricao         object
# grupo                object
# subgrupo             object
# detail               object
# cenario              object
# grupo_empresarial    object
# empresa              object
# dtype: object
