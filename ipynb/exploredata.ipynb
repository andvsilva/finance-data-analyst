# %%
import pandas as pd

# %%
banking = pd.read_csv('../dataset/banking.csv')
banking.drop(["Unnamed: 0"], axis=1, inplace=True)
banking
# Out:
#             date   cca   ccb         descricao  debito  credito  movimentacao  \
# 0     2023-01-13  5791  4598     Charles Berry  528704   845444        591915
# 1     2023-01-17  4506  1997  Angela Castaneda  878870   107754        876933
# 2     2023-01-02  4486  6541     Matthew Burns  975065   439399        538432
# 3     2023-01-13  6371  8401   Katherine Moore  932174   410707        284040
# 4     2023-01-26  8371  9673     Jeanette Ruiz  852688   717632        705934
# ...          ...   ...   ...               ...     ...      ...           ...
# 9995  2022-12-10  1186  8438     Andre Estrada  284525   509171        456724
# 9996  2023-01-19  3993  8669      Daniel Weiss  584521   892479        918967
# 9997  2022-11-14  8047  2236       Robin Allen  723971   585750        591092
# 9998  2022-12-13  1829  7956       Vickie Knox  575221   135313        201695
# 9999  2022-12-28  3037  5749    Arthur Wallace   46277    29823        233624
#
#        cc_id            cc_descricao                             grupo  \
# 0     708693          Tiffany Wilson                             Haiti
# 1     366620  Mrs. Ashley Powell DDS                          Botswana
# 2     486171        Christopher Mann     Holy See (Vatican City State)
# 3     902365           Matthew Baird          Turks and Caicos Islands
# 4     374551          Katie Williams         Bouvet Island (Bouvetoya)
# ...      ...                     ...                               ...
# 9995  114779              Jon Rhodes                             Macao
# 9996  885589           Patricia Kane          Northern Mariana Islands
# 9997  666659           Bradley Moore                           Eritrea
# 9998  316335         Stephanie Ramos                             Gabon
# 9999  794503              John Lynch  Lao People's Democratic Republic
#
#                                           subgrupo             detail  \
# 0                            Accountant, chartered     Ashley Daniels
# 1                                Barrister's clerk      Jessica Brown
# 2                             Licensed conveyancer      Cassie Booker
# 3                                Warehouse manager  Robert Johnson MD
# 4                              Seismic interpreter       Audrey Adams
# ...                                            ...                ...
# 9995                         Pharmacist, community     Robert Daniels
# 9996                                          Land        Anna Wilson
# 9997  Lighting technician, broadcasting/film/video        Jack Tucker
# 9998                   Civil Service fast streamer        Jose Graham
# 9999                            Press photographer    Taylor Guerrero
#
#                        cenario           grupo_empresarial  \
# 0                    Australia                 Iraqi dinar
# 1                   Guadeloupe               Serbian dinar
# 2                    Lithuania       Cayman Islands dollar
# 3     United States of America               Rwandan franc
# 4                      Tokelau               Kuwaiti dinar
# ...                        ...                         ...
# 9995                      Mali            Bangladeshi taka
# 9996                Mauritania          Israeli new shekel
# 9997                   Jamaica             Gibraltar pound
# 9998                  Mongolia  Trinidad and Tobago dollar
# 9999                   Armenia            Ugandan shilling
#
#                      empresa
# 0           Caroline Mcclure
# 1              Anthony Fritz
# 2            Lauren Campbell
# 3               Jacob Abbott
# 4             Mariah Bradley
# ...                      ...
# 9995          Timothy Murray
# 9996  Miss Adrienne Williams
# 9997         Craig Armstrong
# 9998              Bruce Reed
# 9999       Christopher Smith
#
# [10000 rows x 15 columns]

# %%
print(f"Shape dataset Full:.........observations/rows: {banking.shape[0]} and columns: {banking.shape[1]}")
# Out:
# Shape dataset Full:.........observations/rows: 10000 and columns: 15

# %%
banking.dtypes
# Out:
# date                 object
# cca                   int64
# ccb                   int64
# descricao            object
# debito                int64
# credito               int64
# movimentacao          int64
# cc_id                 int64
# cc_descricao         object
# grupo                object
# subgrupo             object
# detail               object
# cenario              object
# grupo_empresarial    object
# empresa              object
# dtype: object
